# %% [markdown]
# ## 文本摘要综述之论文笔记
#
# > [Get To The Point: Summarization with Pointer-Generator Networks](Get To The Point: Summarization with Pointer-Generator Networks)(2017)
#
# > 参考链接:
#
# > [pointer-generator源码](https://github.com/abisee/pointer-generator) ; [我自己运行代码的过程记录](https://blog.csdn.net/weixin_41267423/article/details/78757273) ; [别人根据代码做的中文复述](https://blog.csdn.net/hfutdog/article/details/78447860)
#
# > [该论文作者的博客](http://www.abigailsee.com/2017/04/16/taming-rnns-for-better-summarization.html)
#
# > [参考笔记](https://zhuanlan.zhihu.com/p/27272224)

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ### Baseline——seq2seq+attention
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pointer-generator network
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Coverage mechanism
