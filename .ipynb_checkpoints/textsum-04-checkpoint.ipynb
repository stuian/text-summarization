# %% [markdown]
# ## 文本综述之论文笔记
# >  [A Neural Attention Model for Abstrative Sentence Summarization](https://arxiv.org/pdf/1509.00685.pdf)
#
# >  [NNLM](https://blog.csdn.net/u010089444/article/details/52624964)

# %% [markdown]
# ### 主要模型
#
# 该工作使用提出了一种encoder-decoder框架下的句子摘要模型,对文章的第一个句子进行摘要,生成一个更加精简的句子作为文章的标题.
#
# > 训练数据;English Gigaword;测试数据:DUC2004
#
# 作者在文章中介绍了三种不同的encoding方法，分别为：
#
# - Bag-of-Words Encoder。词袋模型即将输入句子中词的词向量进行平均。
#
# - CNN encoder
#
# - Attention-Based Encoder。该encoder使用CNN对已生成的最近c（c为窗口大小）个词进行编码,再用编码出来的context向量对输入句子做attention，从而实现对输入的加权平均。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 具体算法:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 模型中的decoder为修改过的神经网络语言模型，具体地：式中y_c为已生成的词中大小为c的窗口，与encoder中的Attention-Based Encoder同义。与目前主流的基于seq2seq的模型不同，该模型中encoder并未采用流行的RNN。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 具体算法:
# ![image.png](attachment:image.png)

# %% [markdown]
# > 神经网络语言模型的图示:
#
# ![NNLM](https://img-blog.csdn.net/20160922200454004)

# %% [markdown]
# 生成摘要的公式:
# ![image.png](attachment:image.png)

# %% [markdown]
# 主要有三种方法来求解上式:
#
# - 维特比译码
# - 贪心解码
# - 集束搜索(beam-search)
#
# 最终作者还是选择beam-search:
#
# ![image.png](attachment:image.png)
